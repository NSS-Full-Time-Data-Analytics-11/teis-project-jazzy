# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
excel_data = pd.read_excel('../data/bdi3_data.xlsx')

# %%
csv_data = pd.read_csv('../data/bdi3_data_csv.csv', engine = 'python')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 csv_data = pd.read_csv('../data/bdi3_data_csv.csv', engine = 'python')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %%
bdi3 = excel_dataa

# %%
bdi3
# Out:
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 0        44879      F    2022-09-27              Southwest
# 1        47795      F    2020-12-23      Greater Nashville
# 2        54340      M    2021-06-22        First Tennessee
# 3        54344      F    2022-03-07    Southeast Tennessee
# 4        54515      M    2021-11-04          Memphis Delta
# ...        ...    ...           ...                    ...
# 23942  SP03287      F    2023-09-25          Memphis Delta
# 23943  SP03288      F    2021-05-18          South Central
# 23944  SP03289      F    2021-10-31          South Central
# 23945  SP03290      M    2020-03-25          Memphis Delta
# 23946  SP03291      M    2023-09-18      Greater Nashville
#
#                       Program Label  Adaptive Sum of Scaled Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# ...

# %%
bdi3 = bdi3.drop(columns = {'Code 1'}, axis = 0)

# %%
bdi3 = bdi3.drop(columns = {'Code 2', 'Code 3', 'Code 4', 'Code 5', 'Code 6', 'Code 7', 'Code 8', 'Code 9', 'Code 10'}, axis =0)

# %%
bdi3
# Out:
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 0        44879      F    2022-09-27              Southwest
# 1        47795      F    2020-12-23      Greater Nashville
# 2        54340      M    2021-06-22        First Tennessee
# 3        54344      F    2022-03-07    Southeast Tennessee
# 4        54515      M    2021-11-04          Memphis Delta
# ...        ...    ...           ...                    ...
# 23942  SP03287      F    2023-09-25          Memphis Delta
# 23943  SP03288      F    2021-05-18          South Central
# 23944  SP03289      F    2021-10-31          South Central
# 23945  SP03290      M    2020-03-25          Memphis Delta
# 23946  SP03291      M    2023-09-18      Greater Nashville
#
#                       Program Label  Adaptive Sum of Scaled Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# ...

# %%
bdi3.duplicated().value_counts()
# Out:
# False    19500
# True      4447
# Name: count, dtype: int64

# %%
bdi3.Gender.value_counts()
# Out:
# Gender
# M    14732
# F     8801
# U      414
# Name: count, dtype: int64

# %%
duplicate_rows = bdi3[bdi3.duplicated()]

# %%
bdi3_df = bdi3.drop_duplicates()

# %%
bdi3_df
# Out:
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 0        44879      F    2022-09-27              Southwest
# 1        47795      F    2020-12-23      Greater Nashville
# 2        54340      M    2021-06-22        First Tennessee
# 3        54344      F    2022-03-07    Southeast Tennessee
# 4        54515      M    2021-11-04          Memphis Delta
# ...        ...    ...           ...                    ...
# 23942  SP03287      F    2023-09-25          Memphis Delta
# 23943  SP03288      F    2021-05-18          South Central
# 23944  SP03289      F    2021-10-31          South Central
# 23945  SP03290      M    2020-03-25          Memphis Delta
# 23946  SP03291      M    2023-09-18      Greater Nashville
#
#                       Program Label  Adaptive Sum of Scaled Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# ...

# %%
bdi3_df.describe()
# Out:
#                        Date of Birth  Adaptive Sum of Scaled Scores  \
# count                          19500                   19493.000000
# mean   2021-08-26 01:54:18.830769152                      11.412712
# min              2019-10-15 00:00:00                       1.000000
# 25%              2020-12-11 00:00:00                       7.000000
# 50%              2021-07-21 00:00:00                      11.000000
# 75%              2022-04-12 00:00:00                      15.000000
# max              2023-10-30 00:00:00                      36.000000
# std                              NaN                       5.822943
#
#        Adaptive Developmental Quotient  Adaptive T-Score  \
# count                     19493.000000      19493.000000
# mean                         87.435079         41.624583
# min                          46.000000         14.000000
# 25%                          76.000000         34.000000
# 50%                          88.000000         42.000000
# ...

# %%
bdi3_df.Gender.value_counts()
# Out:
# Gender
# M    11960
# F     7246
# U      294
# Name: count, dtype: int64

# %%
bdi3_df.columns
# Out:
# Index(['Child ID', 'Gender', 'Date of Birth', 'Location - Sub Level 1',
#        'Program Label', 'Adaptive Sum of Scaled Scores',
#        'Adaptive Developmental Quotient', 'Adaptive Percentile Rank',
#        'Adaptive 95% Confidence Interval', 'Adaptive RDI',
#        ...
#        'Cognitive-Perception and Concepts RS',
#        'Cognitive-Perception and Concepts SS',
#        'Cognitive-Perception and Concepts PR',
#        'Cognitive-Perception and Concepts AE',
#        'Cognitive-Perception and Concepts RDI',
#        'Cognitive-Perception and Concepts CSS',
#        'Cognitive-Perception and Concepts CSS 90%',
#        'Cognitive-Perception and Concepts Z-Score',
#        'Cognitive-Perception and Concepts T-Score',
#        'Cognitive-Perception and Concepts NCE'],
#       dtype='object', length=209)

# %%
bdi3_df.shape
# Out:
# (19500, 209)

# %%
bdi3_df.head()
# Out:
#   Child ID Gender Date of Birth Location - Sub Level 1  \
# 0    44879      F    2022-09-27              Southwest
# 1    47795      F    2020-12-23      Greater Nashville
# 2    54340      M    2021-06-22        First Tennessee
# 3    54344      F    2022-03-07    Southeast Tennessee
# 4    54515      M    2021-11-04          Memphis Delta
#
#                   Program Label  Adaptive Sum of Scaled Scores  \
# 0  BDI-3 Eligibility Evaluation                            7.0
# 1  BDI-3 Eligibility Evaluation                           16.0
# 2  BDI-3 Eligibility Evaluation                            8.0
# 3  BDI-3 Eligibility Evaluation                           13.0
# 4  BDI-3 Eligibility Evaluation                            5.0
#
#    Adaptive Developmental Quotient Adaptive Percentile Rank  \
# 0                             85.0                       16
# 1                             88.0                       21
# 2                             90.0                       25
# ...

# %%
bdi3_df.columns
# Out:
# Index(['Child ID', 'Gender', 'Date of Birth', 'Location - Sub Level 1',
#        'Program Label', 'Adaptive Sum of Scaled Scores',
#        'Adaptive Developmental Quotient', 'Adaptive Percentile Rank',
#        'Adaptive 95% Confidence Interval', 'Adaptive RDI',
#        ...
#        'Cognitive-Perception and Concepts RS',
#        'Cognitive-Perception and Concepts SS',
#        'Cognitive-Perception and Concepts PR',
#        'Cognitive-Perception and Concepts AE',
#        'Cognitive-Perception and Concepts RDI',
#        'Cognitive-Perception and Concepts CSS',
#        'Cognitive-Perception and Concepts CSS 90%',
#        'Cognitive-Perception and Concepts Z-Score',
#        'Cognitive-Perception and Concepts T-Score',
#        'Cognitive-Perception and Concepts NCE'],
#       dtype='object', length=209)

# %%
bdi3_df.groupby('Gender')['Adaptive Sum of Scaled Scores'].mean()
# Out:
# Gender
# F    11.469289
# M    11.352685
# U    12.459184
# Name: Adaptive Sum of Scaled Scores, dtype: float64

# %%
bdi3_df.groupby('Gender')['Adaptive Developmental Quotient'].describe()
# Out:
#           count       mean        std   min   25%   50%    75%    max
# Gender
# F        7245.0  89.246515  17.981322  46.0  79.0  90.0  103.0  148.0
# M       11954.0  86.281914  17.073240  46.0  76.0  88.0  100.0  145.0
# U         294.0  89.683673  14.323134  46.0  80.0  90.5  100.0  130.0

# %%
middle_tn = bdi3_df.loc[(bdi3['Location - Sub Level 1'] == 'Greater Nashville') | (bdi3['Location - Sub Level 1'] == 'Upper Cumberland') | (bdi3['Location - Sub Level 1'] == 'South Central')]

# %%
middle_tn
# Out:
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 1        47795      F    2020-12-23      Greater Nashville
# 9        55182      F    2022-07-06       Upper Cumberland
# 16       56077      F    2022-11-11          South Central
# 19      404042      M    2020-03-17       Upper Cumberland
# 23      436346      F    2022-09-01          South Central
# ...        ...    ...           ...                    ...
# 23932  SP03277      F    2023-04-03       Upper Cumberland
# 23935  SP03280      M    2023-04-16       Upper Cumberland
# 23943  SP03288      F    2021-05-18          South Central
# 23944  SP03289      F    2021-10-31          South Central
# 23946  SP03291      M    2023-09-18      Greater Nashville
#
#                       Program Label  Adaptive Sum of Scaled Scores  \
# 1      BDI-3 Eligibility Evaluation                           16.0
# 9      BDI-3 Eligibility Evaluation                           10.0
# ...

# %%
middle_tn['Adaptive Developmental Quotient'].describe()
# Out:
# count    8015.000000
# mean       87.765814
# std        17.529331
# min        46.000000
# 25%        76.000000
# 50%        90.000000
# 75%       100.000000
# max       148.000000
# Name: Adaptive Developmental Quotient, dtype: float64

# %%
sns.boxplot(x = middle_tn['Adaptive Developmental Quotient'])
# Out:
# <Axes: xlabel='Adaptive Developmental Quotient'>

# %%
sns.boxplot(x = middle_tn['Social-Emotional Developmental Quotient'])
# Out:
# <Axes: xlabel='Social-Emotional Developmental Quotient'>

# %%
sns.boxplot(x = middle_tn['Communication Developmental Quotient'])
# Out:
# <Axes: xlabel='Communication Developmental Quotient'>

# %%
sns.boxplot(x = middle_tn['Motor Developmental Quotient'])
# Out:
# <Axes: xlabel='Motor Developmental Quotient'>

# %%
sns.boxplot(x = middle_tn['Cognitive Developmental Quotient'])
# Out:
# <Axes: xlabel='Cognitive Developmental Quotient'>

# %% [markdown]
# I'm seeing a lot of outliers on both ends for Motor DQ and Communcation DQ in middle TN. I used gender to split htis up but I'm also interested in segmenting by age

# %%
middle_tn['Date of Birth'].sort_values()
# Out:
# 75      2019-10-17
# 2361    2019-10-18
# 5035    2019-10-19
# 312     2019-10-20
# 1573    2019-10-20
#            ...
# 20118   2023-10-15
# 20184   2023-10-17
# 20127   2023-10-22
# 20304   2023-10-23
# 20262   2023-10-28
# Name: Date of Birth, Length: 8017, dtype: datetime64[ns]

# %%
bdi3_df.corr(numeric_only=True)
# Out:
#                                                Adaptive Sum of Scaled Scores  \
# Adaptive Sum of Scaled Scores                                       1.000000
# Adaptive Developmental Quotient                                     0.681547
# Adaptive T-Score                                                    0.681493
# Social-Emotional Sum of Scaled Scores                               0.713947
# Social-Emotional Developmental Quotient                             0.354115
# ...                                                                      ...
# Cognitive-Reasoning / Academic Skills T-Score                       0.528359
# Cognitive-Perception and Concepts RS                                0.554702
# Cognitive-Perception and Concepts SS                                0.179760
# Cognitive-Perception and Concepts CSS                               0.545377
# Cognitive-Perception and Concepts T-Score                           0.178862
#
# ...

# %%
bdi3_df['Adaptive Percentile Rank'].astype(str)
# Out:
# 0        16
# 1        21
# 2        25
# 3        84
# 4         5
#          ..
# 23942    84
# 23943    84
# 23944    58
# 23945    21
# 23946    63
# Name: Adaptive Percentile Rank, Length: 19500, dtype: object

# %%
bdi3_df['Adaptive Percentile Rank'].astype(str)
# Out:
# 0        16
# 1        21
# 2        25
# 3        84
# 4         5
#          ..
# 23942    84
# 23943    84
# 23944    58
# 23945    21
# 23946    63
# Name: Adaptive Percentile Rank, Length: 19500, dtype: object

# %%
columns = [col for col in bdi3_df.columns if 'Z-Score' in col]

# %%
for column in columns:
    print(bdi3_df[column])
# Out:
# 0        – 1.00
# 1        – 0.80
# 2        – 0.67
# 3             1
# 4        – 1.67
#           ...
# 23942         1
# 23943         1
# 23944       0.2
# 23945    – 0.80
# 23946      0.33
# Name: Adaptive Z-Score, Length: 19500, dtype: object
# 0           1.8
# 1          0.27
# 2        – 0.60
# 3           0.2
# 4        – 1.80
#           ...
# 23942         1
# 23943      1.07
# 23944      0.13
# 23945    – 0.67
# 23946    – 0.20
# Name: Social-Emotional Z-Score, Length: 19500, dtype: object
# 0        – 0.60
# 1        – 0.20
# 2        – 1.20
# 3        – 0.80
# 4        – 2.00
#           ...
# 23942       0.8
# 23943       0.8
# 23944    – 3.00
# 23945    – 1.60
# 23946         0
# Name: Communication Z-Score, Length: 19500, dtype: object
# 0        – 0.80
# 1          0.13
# 2           0.6
# 3        – 0.60
# 4        – 1.80
#           ...
# 23942       1.2
# 23943      1.13
# 23944      0.27
# 23945         0
# 23946         0
# ...
